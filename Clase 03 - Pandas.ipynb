# %% [markdown]
# ![](https://pandas.pydata.org/_static/pandas_logo.png)

# %% [markdown]
# #### **Pandas** es una librería de Python que provee herramientas para análisis de datos, proporciona estructuras de datos flexibles y muy eficientes.
#
#  - Series: Arreglos unidimensionales (P. ej: Series temporales)
#  - DataFrame: Son estructuras de datos similares a las tablas.
#  - Panel, Panel4D y PanelND: Para trabajar con datos multidimensiones (> 2 dim).

# %% [markdown]
# ### Importamos la librería

# %% [markdown]
# Es convención utilizar el alias **pd** cuando se va a trabajar con **pandas**

# %%
import pandas as pd

# %% [markdown]
# ### Abriendo archivos de datos

# %% [markdown]
# Desde un csv (pasandole la ruta al archivo)

# %% [markdown]
# `df_csv = pd.read_csv("ruta/archivo.csv")`

# %% [markdown]
# Desde un xls

# %% [markdown]
# `df_xls = pd.read_excel("ruta/archivo.xls")`

# %% [markdown]
# Desde otras fuentes de datos

# %% [markdown]
# - `pd.read_clipboard(*args)`
# - `pd.read_hdf(*args)`
# - `pd.read_html(*args)`
# - `pd.read_json(*args)`
# - `pd.read_pickle(*args)`
# - etc.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# [Descripción del dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# Según el caso, utilizaremos la función que corresponda para abrir nuestro archivo de datos.
#
# Como resultado obtendremos una estructura de datos como las mencionadas anteriormente.
#
# Se suele usar el prefijo **df** dando a entender que la variable aloja un DataFrame.

# %% [markdown]
# ### Exploración de los datos

# %% [markdown]
# Primeros 5 elementos

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Primeros N elementos

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Últimos 5 elementos

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Últimos N elementos

# %%
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %% [markdown]
# Cantidad total de filas

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# Nombres de las columnas

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Subconjunto de columnas

# %%
df.iloc[:, 2:8] # todas las filas, pero solo los datos de las columnas 2 hasta la 8 inclusive (el indice comienza en 0)
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch
# 0        1      0
# ...

# %% [markdown]
# Subconjuntos de filas

# %%
df.iloc[:100, 2:8] # las primeras 100 filas, pero solo los datos de las columnas 2 hasta la 8 inclusive (el indice comienza en 0)
# Out:
#     Pclass                                               Name     Sex   Age  \
# 0        3                            Braund, Mr. Owen Harris    male  22.0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2        3                             Heikkinen, Miss. Laina  female  26.0
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4        3                           Allen, Mr. William Henry    male  35.0
# ..     ...                                                ...     ...   ...
# 95       3                        Shorney, Mr. Charles Joseph    male   NaN
# 96       1                          Goldschmidt, Mr. George B    male  71.0
# 97       1                    Greenfield, Mr. William Bertram    male  23.0
# 98       2               Doling, Mrs. John T (Ada Julia Bone)  female  34.0
# 99       2                                  Kantor, Mr. Sinai    male  34.0
#
#     SibSp  Parch
# 0       1      0
# 1       1      0
# ...

# %% [markdown]
# Subconjunto de columnas (con nombres)

# %%
df[["Survived", "Sex", "Age"]] #De utilidad cuando las columnas con las que queremos trabajar no son contiguas
# Out:
#      Survived     Sex   Age
# 0           0    male  22.0
# 1           1  female  38.0
# 2           1  female  26.0
# 3           1  female  35.0
# 4           0    male  35.0
# ..        ...     ...   ...
# 886         0    male  27.0
# 887         1  female  19.0
# 888         0  female   NaN
# 889         1    male  26.0
# 890         0    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# ### Otras operaciones

# %% [markdown]
# #### Describir los datos

# %%
df.describe() #notese que solo describe datos numéricos
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### Contando datos faltantes (NA's o NAN)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### Eliminando datos faltantes

# %%
df.dropna(how="any") # el parámetro how puede ser "any" o "all"
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Reemplazando datos faltantes con otro valor

# %%
df.fillna(value=9999) # se reemplaza NA sobre todas las columnas pero se pueden asignar diferentes valores a columnas individuales.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 2                               Heikkinen, Miss. Laina  female    26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 4                             Allen, Mr. William Henry    male    35.0      0
# ...

# %% [markdown]
# #### Contamos los NAs luego de aplicar el reemplazo de valores

# %%
df.fillna(value=9999).isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Datos duplicados (buscar, contar, eliminar)

# %% [markdown]
# Vamos a fabricar nuestros datos duplicados tomando los primeros 5 y reinsertándolos al final

# %%
fake_dup = df.head()

# %%
df_dup = df.append(fake_dup)

# %% [markdown]
# Filtramos datos duplicados con una máscara booleana

# %%
df_dup[df_dup.duplicated()]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Contamos los datos duplicados (a nivel columna)

# %%
df_dup[df_dup.duplicated()].count()
# Out:
# PassengerId    5
# Survived       5
# Pclass         5
# Name           5
# Sex            5
# Age            5
# SibSp          5
# Parch          5
# Ticket         5
# Fare           5
# Cabin          2
# Embarked       5
# dtype: int64

# %% [markdown]
# Contamos los datos duplicados (en general)

# %%
df_dup[df_dup.duplicated()].shape
# Out:
# (5, 12)

# %% [markdown]
# #### Cambiar/Reemplazar los nombres de las columnas

# %%
viejos_nombres = df.columns
nuevos_nombres = ['Id', 'Sobrevivió', 'Clase de pasajero', 'Nombre', 'Sexo', 'Edad', '#Hermanos/Cónyuges abordo', '#Padres/hijos abordo', 'Ticket', 'Tarifa', 'Cabina', 'Puerto de embarcación']

# %%
df.columns = nuevos_nombres #nuevos_nombres tiene que tener la misma cantidad de elementos que viejos_nombres para que no ocurran errores

# %%
df.head()
# Out:
#    Id  Sobrevivió  Clase de pasajero  \
# 0   1           0                  3
# 1   2           1                  1
# 2   3           1                  3
# 3   4           1                  1
# 4   5           0                  3
#
#                                               Nombre    Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    #Hermanos/Cónyuges abordo  #Padres/hijos abordo            Ticket   Tarifa  \
# 0                          1                     0         A/5 21171   7.2500
# 1                          1                     0          PC 17599  71.2833
# 2                          0                     0  STON/O2. 3101282   7.9250
# ...

# %% [markdown]
# #### Obtener valores únicos

# %%
df["Puerto de embarcación"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# #### Contar ocurrencias

# %%
df[df["Puerto de embarcación"] == "C"].count() # Contar cuantos pasajeros embarcaron en el puerto "C"
# Out:
# Id                           168
# Sobrevivió                   168
# Clase de pasajero            168
# Nombre                       168
# Sexo                         168
# Edad                         130
# #Hermanos/Cónyuges abordo    168
# #Padres/hijos abordo         168
# Ticket                       168
# Tarifa                       168
# Cabina                        69
# Puerto de embarcación        168
# dtype: int64

# %%
df[df["Puerto de embarcación"] == 'C' ]["Id"].count() # Contar los Ids de los pasajeros embarcaron en el puerto "C"
# Out:
# 168

# %% [markdown]
# #### Trasponer los datos (invertir filas <-> columnas)

# %%
df.T
# Out:
#                                                0    \
# Id                                               1
# Sobrevivió                                       0
# Clase de pasajero                                3
# Nombre                     Braund, Mr. Owen Harris
# Sexo                                          male
# Edad                                            22
# #Hermanos/Cónyuges abordo                        1
# #Padres/hijos abordo                             0
# Ticket                                   A/5 21171
# Tarifa                                        7.25
# Cabina                                         NaN
# Puerto de embarcación                            S
#
#                                                                          1    \
# Id                                                                         2
# Sobrevivió                                                                 1
# ...

# %% [markdown]
# #### Ordenar datos

# %%
df.sort_values("Nombre")
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 845  846           0                  3
# 746  747           0                  3
# 279  280           1                  3
# 308  309           0                  2
# 874  875           1                  2
# ..   ...         ...                ...
# 286  287           1                  3
# 282  283           0                  3
# 361  362           0                  2
# 153  154           0                  3
# 868  869           0                  3
#
#                                     Nombre    Sexo  Edad  \
# 845                    Abbing, Mr. Anthony    male  42.0
# 746            Abbott, Mr. Rossmore Edward    male  16.0
# 279       Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0
# 308                    Abelson, Mr. Samuel    male  30.0
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# ..                                     ...     ...   ...
# 286                de Mulder, Mr. Theodore    male  30.0
# ...

# %%
df.sort_values("Nombre", ascending=False)
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 868  869           0                  3
# 153  154           0                  3
# 361  362           0                  2
# 282  283           0                  3
# 286  287           1                  3
# ..   ...         ...                ...
# 874  875           1                  2
# 308  309           0                  2
# 279  280           1                  3
# 746  747           0                  3
# 845  846           0                  3
#
#                                     Nombre    Sexo  Edad  \
# 868            van Melkebeke, Mr. Philemon    male   NaN
# 153        van Billiard, Mr. Austin Blyler    male  40.5
# 361              del Carlo, Mr. Sebastiano    male  29.0
# 282              de Pelsmaeker, Mr. Alfons    male  16.0
# 286                de Mulder, Mr. Theodore    male  30.0
# ..                                     ...     ...   ...
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# ...

# %%
df.sort_values(["Sexo", "Sobrevivió"]) # Ordenar teniendo en cuenta varios factores
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 14    15           0                  3
# 18    19           0                  3
# 24    25           0                  3
# 38    39           0                  3
# 40    41           0                  3
# ..   ...         ...                ...
# 838  839           1                  3
# 839  840           1                  1
# 857  858           1                  1
# 869  870           1                  3
# 889  890           1                  1
#
#                                                 Nombre    Sexo  Edad  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 24                       Palsson, Miss. Torborg Danira  female   8.0
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# ...

# %% [markdown]
# #### Selección de datos

# %%
df["Nombre"] # Trabajamos con todos los datos de la columna "Nombre"
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Nombre, Length: 891, dtype: object

# %%
df["Nombre"][5] # Obtenemos el sexto nombre (indices comienzan en cero)
# Out:
# 'Moran, Mr. James'

# %%
df.at[5, "Nombre"] #equivalente al anterior, queremos el valor de "Nombre" para el sexto renglon
# Out:
# 'Moran, Mr. James'

# %% [markdown]
# Selección por posición

# %%
df[0:3] # Trabajamos con los primeros 3 renglones. Esta forma de indexar solo funciona con renglones -> no podremos filtrar columnas
# Out:
#    Id  Sobrevivió  Clase de pasajero  \
# 0   1           0                  3
# 1   2           1                  1
# 2   3           1                  3
#
#                                               Nombre    Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
#
#    #Hermanos/Cónyuges abordo  #Padres/hijos abordo            Ticket   Tarifa  \
# 0                          1                     0         A/5 21171   7.2500
# 1                          1                     0          PC 17599  71.2833
# 2                          0                     0  STON/O2. 3101282   7.9250
#
#   Cabina Puerto de embarcación
# 0    NaN                     S
# 1    C85                     C
# 2    NaN                     S

# %%
df.iloc[0:3] # Equivalente al anterior pero permite filtrar columnas
# Out:
#    Id  Sobrevivió  Clase de pasajero  \
# 0   1           0                  3
# 1   2           1                  1
# 2   3           1                  3
#
#                                               Nombre    Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
#
#    #Hermanos/Cónyuges abordo  #Padres/hijos abordo            Ticket   Tarifa  \
# 0                          1                     0         A/5 21171   7.2500
# 1                          1                     0          PC 17599  71.2833
# 2                          0                     0  STON/O2. 3101282   7.9250
#
#   Cabina Puerto de embarcación
# 0    NaN                     S
# 1    C85                     C
# 2    NaN                     S

# %%
df.iloc[0:3, :4] # Filtrando las primeras 4 columnas
# Out:
#    Id  Sobrevivió  Clase de pasajero  \
# 0   1           0                  3
# 1   2           1                  1
# 2   3           1                  3
#
#                                               Nombre
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina

# %% [markdown]
# Selección por etiqueta/label

# %%
df.loc[:10, ["Nombre", "Sobrevivió"]] #loc nos permite trabajar con subconjuntos de renglones de una columna o conjunto de columnas pasandole el nombre de las mismas
# Out:
#                                                Nombre  Sobrevivió
# 0                             Braund, Mr. Owen Harris           0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2                              Heikkinen, Miss. Laina           1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# 4                            Allen, Mr. William Henry           0
# 5                                    Moran, Mr. James           0
# 6                             McCarthy, Mr. Timothy J           0
# 7                      Palsson, Master. Gosta Leonard           0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)           1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)           1
# 10                    Sandstrom, Miss. Marguerite Rut           1

# %% [markdown]
# #### Filtrado de datos usando máscaras booleanas

# %%
df["Edad"] > 28
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Edad, Length: 891, dtype: bool

# %%
df[df.Edad > 50] # Filtramos valores basandonos en la máscara booleana
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 6      7           0                  1
# 11    12           1                  1
# 15    16           1                  2
# 33    34           0                  2
# 54    55           0                  1
# ..   ...         ...                ...
# 820  821           1                  1
# 829  830           1                  1
# 851  852           0                  3
# 857  858           1                  1
# 879  880           1                  1
#
#                                                 Nombre    Sexo  Edad  \
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 33                               Wheadon, Mr. Edward H    male  66.0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0
# ...

# %%
df[df.Edad.isin([30, 40, 50])] # Pasajeros con 30, 40 o 50 años
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 30    31           0                  1
# 40    41           0                  3
# 79    80           1                  3
# 157  158           0                  3
# 161  162           1                  2
# 177  178           0                  1
# 178  179           0                  2
# 188  189           0                  3
# 209  210           1                  1
# 213  214           0                  2
# 219  220           0                  2
# 244  245           0                  3
# 253  254           0                  3
# 257  258           1                  1
# 259  260           1                  2
# 263  264           0                  1
# 286  287           1                  3
# 299  300           1                  1
# 308  309           0                  2
# 309  310           1                  1
# 319  320           1                  1
# 322  323           1                  2
# ...

# %% [markdown]
# #### Agrupar datos según alguna condición

# %%
subconj = df[df.Edad.isin([30, 40, 50])] # Pasajeros con 30, 40 o 50 años
promedio_grupo = subconj.groupby(["Sexo", "Sobrevivió"]).mean()
promedio_grupo
# Out:
#                            Id  Clase de pasajero       Edad  \
# Sexo   Sobrevivió
# female 0           388.500000           2.500000  37.500000
#        1           444.666667           1.611111  37.222222
# male   0           389.913043           2.304348  36.086957
#        1           386.000000           1.666667  40.000000
#
#                    #Hermanos/Cónyuges abordo  #Padres/hijos abordo     Tarifa
# Sexo   Sobrevivió
# female 0                            0.500000              0.250000  17.750000
#        1                            0.277778              0.222222  60.189583
# male   0                            0.260870              0.217391  18.811591
#        1                            0.666667              0.000000  58.050000

# %%
promedio_grupo["Edad"]
# Out:
# Sexo    Sobrevivió
# female  0             37.500000
#         1             37.222222
# male    0             36.086957
#         1             40.000000
# Name: Edad, dtype: float64

# %% [markdown]
# #### Juntar 2 DataFrames que comparten las mismas columnas

# %%
# Vamos a dividir artificialmente el df en 2 (mas o menos)
df_1 = df[445:]
df_2 = df[:445]

# %%
df_1.shape # tenemos los primeros 445 renglones del dataset original
# Out:
# (446, 12)

# %%
df_1.tail(1)
# Out:
#       Id  Sobrevivió  Clase de pasajero               Nombre  Sexo  Edad  \
# 890  891           0                  3  Dooley, Mr. Patrick  male  32.0
#
#      #Hermanos/Cónyuges abordo  #Padres/hijos abordo  Ticket  Tarifa Cabina  \
# 890                          0                     0  370376    7.75    NaN
#
#     Puerto de embarcación
# 890                     Q

# %%
df_2.shape # tenemos los elementos restantes del dataset original a partir del 446
# Out:
# (445, 12)

# %%
df_2.head()
# Out:
#    Id  Sobrevivió  Clase de pasajero  \
# 0   1           0                  3
# 1   2           1                  1
# 2   3           1                  3
# 3   4           1                  1
# 4   5           0                  3
#
#                                               Nombre    Sexo  Edad  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    #Hermanos/Cónyuges abordo  #Padres/hijos abordo            Ticket   Tarifa  \
# 0                          1                     0         A/5 21171   7.2500
# 1                          1                     0          PC 17599  71.2833
# 2                          0                     0  STON/O2. 3101282   7.9250
# ...

# %% [markdown]
# #### Añadimos renglones a un DataFrame con la función `append()`

# %%
df_3 = df_1.append(df_2) # Devuelve un nuevo DataFrame con el resultado

# %%
df_1.shape, df_2.shape # Los tamaños originales se mantienen
# Out:
# ((446, 12), (445, 12))

# %%
df_3.shape
# Out:
# (891, 12)

# %%
df_3
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 445  446           1                  1
# 446  447           1                  2
# 447  448           1                  1
# 448  449           1                  3
# 449  450           1                  1
# ..   ...         ...                ...
# 440  441           1                  2
# 441  442           0                  3
# 442  443           0                  3
# 443  444           1                  2
# 444  445           1                  3
#
#                                           Nombre    Sexo  Edad  \
# 445                    Dodge, Master. Washington    male   4.0
# 446            Mellinger, Miss. Madeleine Violet  female  13.0
# 447                  Seward, Mr. Frederic Kimber    male  34.0
# 448               Baclini, Miss. Marie Catherine  female   5.0
# 449               Peuchen, Major. Arthur Godfrey    male  52.0
# ..                                           ...     ...   ...
# ...

# %% [markdown]
# #### Añadir nuevas columnas a un DataFrame existente. `assign()`

# %%
import numpy as np

# %%
alturas = np.random.uniform(1.5, 2.0, df.shape[0]) #Creamos valores de altura aleatorios entre (1.5 y 2.0 mts)

# %%
df_con_alturas = df.assign(Altura=alturas) # Devuelve un nuevo DataFrame
df_con_alturas
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                                 Nombre    Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %%
df
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                                 Nombre    Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# #### Añadir columnas desde otro DataFrame compartiendo una columna (generalmente un Id)     `join()` o `merge()`

# %%
df_1 = df.iloc[:, :3] #Creamos un subconjunto de datos que tenga algunas columnas (incluyendo la columna "Id")
df_1
# Out:
#       Id  Sobrevivió  Clase de pasajero
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
# [891 rows x 3 columns]

# %%
df_2 = df.iloc[:, 3:] # Creamos otro subconjunto que contenga las columnas restantes
df_2 = df_2.assign(Id=df[["Id"]]) #Agregamos la columna "Id" al final para que los subconjuntos tengan una columna en común
df_2
# Out:
#                                                 Nombre    Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      #Hermanos/Cónyuges abordo  #Padres/hijos abordo            Ticket  \
# ...

# %%
df_3 = df_1.join(df_2, on=["Id"], rsuffix="rId") #Realizamos el join sobre la columna "Id", manteniendo la columna Id de la 2da tabla con el nombre "rId"

# %%
df_3
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                                 Nombre    Sexo  Edad  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1                               Heikkinen, Miss. Laina  female  26.0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                             Allen, Mr. William Henry    male  35.0
# 4                                     Moran, Mr. James    male   NaN
# ...

# %% [markdown]
# Equivalente a la anterior (no duplica la columna en común)

# %%
df_4 = df_1.merge(df_2, on="Id")

# %%
df_4
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                                 Nombre    Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# #### Juntar 2 DataFrames que NO comparten las mismas columnas. `append()`

# %%
df_1 = df[:445] #Dividimos el dataset en la mitad (mas o menos)
df_2 = df[445:]

# %%
df_2.shape
# Out:
# (446, 12)

# %%
alturas = np.random.uniform(1.5, 2.0, df_2.shape[0]) #Creamos valores de altura aleatorios entre (1.5 y 2.0 mts) para el DataFrame "df_2"
df_2 = df_2.assign(Altura=alturas)
df_2
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 445  446           1                  1
# 446  447           1                  2
# 447  448           1                  1
# 448  449           1                  3
# 449  450           1                  1
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                        Nombre    Sexo  Edad  \
# 445                 Dodge, Master. Washington    male   4.0
# 446         Mellinger, Miss. Madeleine Violet  female  13.0
# 447               Seward, Mr. Frederic Kimber    male  34.0
# 448            Baclini, Miss. Marie Catherine  female   5.0
# 449            Peuchen, Major. Arthur Godfrey    male  52.0
# ..                                        ...     ...   ...
# ...

# %%
df_3 = df_1.append(df_2)
df_3
# Out:
# /home/bruno/Envs/ml-tools/lib/python3.8/site-packages/pandas/core/frame.py:7134: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return concat(
#      #Hermanos/Cónyuges abordo  #Padres/hijos abordo    Altura Cabina  \
# 0                            1                     0       NaN    NaN
# 1                            1                     0       NaN    C85
# 2                            0                     0       NaN    NaN
# 3                            1                     0       NaN   C123
# 4                            0                     0       NaN    NaN
# ..                         ...                   ...       ...    ...
# 886                          0                     0  1.938755    NaN
# ...

# %%
df_3["Altura"].isna().sum() #Añadió sin problemas pero hay valores NA en el subconjunto que no tenía la columna "Altura"
# Out:
# 445

# %% [markdown]
# #### Combinar múltiples DataFrames que comparten todas sus columnas pero tienen diferentes datos. `pd.concat()`

# %%
df_1 = df[:100] #Dividimos el dataset en 3
df_2 = df[100:345]
df_3 = df[345:]

# %%
df_4 = pd.concat([df_1, df_2, df_3]) # Pasamos la lista de dataframes a combinar como parámetro

# %%
df_4
# Out:
#       Id  Sobrevivió  Clase de pasajero  \
# 0      1           0                  3
# 1      2           1                  1
# 2      3           1                  3
# 3      4           1                  1
# 4      5           0                  3
# ..   ...         ...                ...
# 886  887           0                  2
# 887  888           1                  1
# 888  889           0                  3
# 889  890           1                  1
# 890  891           0                  3
#
#                                                 Nombre    Sexo  Edad  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# #### Como crear un DataFrame

# %% [markdown]
# A través de un diccionario

# %%
alturas = np.random.uniform(1.5, 2.0, 10)
edades = np.random.uniform(18, 99, 10)
datos = {"Altura": alturas, "Edad": edades}

# %%
df_5 = pd.DataFrame(data=datos) #Las columnas deben tener igual cantidad de datos
df_5
# Out:
#      Altura       Edad
# 0  1.532372  32.964473
# 1  1.808992  65.844320
# 2  1.787153  20.927738
# 3  1.881450  25.047132
# 4  1.554562  42.860993
# 5  1.525118  90.892253
# 6  1.613113  74.021218
# 7  1.529922  84.051075
# 8  1.935895  97.885144
# 9  1.695806  43.970414

# %% [markdown]
# Creando un DataFrame vacío con los nombres de las columnas y completando los datos después

# %%
df_6 = pd.DataFrame(columns=("Altura", "Edad"))
df_6
# Out:
# Empty DataFrame
# Columns: [Altura, Edad]
# Index: []

# %%
df_6.Edad = edades
df_6
# Out:
#   Altura       Edad
# 0    NaN  32.964473
# 1    NaN  65.844320
# 2    NaN  20.927738
# 3    NaN  25.047132
# 4    NaN  42.860993
# 5    NaN  90.892253
# 6    NaN  74.021218
# 7    NaN  84.051075
# 8    NaN  97.885144
# 9    NaN  43.970414

# %%
df_6.Altura = alturas # Las columnas deben tener la misma cantidad de valores
df_6
# Out:
#      Altura       Edad
# 0  1.532372  32.964473
# 1  1.808992  65.844320
# 2  1.787153  20.927738
# 3  1.881450  25.047132
# 4  1.554562  42.860993
# 5  1.525118  90.892253
# 6  1.613113  74.021218
# 7  1.529922  84.051075
# 8  1.935895  97.885144
# 9  1.695806  43.970414

# %% [markdown]
# ### Graficar valores

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# Líneas

# %%
df_6[["Edad"]].plot(kind='line')

# %% [markdown]
# Agregamos labels y cambiamos el color de la linea

# %%
df_6[["Altura"]].plot(kind='line', color="orange")
plt.ylabel("Altura en mts")
plt.xlabel("Individuo")
# Out:
# Text(0.5, 0, 'Individuo')

# %% [markdown]
# Scatter - Cambiamos el color de los puntos y agregamos el título del gráfico

# %%
df_6.plot(kind='scatter', x="Edad", y="Altura", color="green", title="Alturas y Edades")

# %% [markdown]
# Barras - desactivamos la leyenda del gráfico

# %%
df_6.plot(kind='bar', x="Edad", y="Altura", legend=False)

# %% [markdown]
# Guardamos un plot con `plt.savefig()`

# %%
#rcParams.figSize = (10, 20)

# %%
ax = df_6.plot(kind='bar', x="Edad", y="Altura", legend=False, title="Altura y edades")
ax.set_ylabel("Altura")
ax.set_xlabel("Edad")
plt.savefig("mi_grafico_de_barras.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Más info (Pandas y Matplotlib): http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %% [markdown]
# #### Guardamos los datos

# %% [markdown]
# ##### Después de trabajar con pandas, es recomendable guardar tus datos o los resultados que hayas obtenido.
#
# Para eso, podés usar una de las siguientes funciones:
#
# - `df.to_csv(*args)`
# - `df.to_excel(*args)`
# - `df.to_clipboard(*args)`
# - `df.to_hdf(*args)`
# - `df.to_html(*args)`
# - `df.to_json(*args)`
# - `df.to_pickle(*args)`
# - [más](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#serialization-io-conversion).

# %% [markdown]
# **Observación**: Notá que las funciones se invocan desde la estructura de datos que estés usando, en este caso **df** denota el uso de un DataFrame. Otras estructuras permiten invocar funciones similares.

# %%
df_1 = df[:100]
df_1.to_csv('los_primeros_100.csv')

# %% [markdown]
# #### A practicar :D
