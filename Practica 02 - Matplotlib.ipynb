# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Graficar la siguiente función:

# %%
X = np.arange(1, 101)
Y =  np.random.random_sample(100)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)# *nrows*, *ncols*, and *index*
ax.set_title('UN TITULO')
ax.set_ylabel('Y')
ax.set_xlabel('X')
ax.grid()

# %% [markdown]
# ## Graficar la siguiente función:

# %%
X = np.arange(1, 101)
Y =  np.random.lognormal(size=(100))

# %% [markdown]
# ## Dado $F(x) = ax + b$ con $x > 1$ y $x<=100$, graficar:
#
# ### Grafico 1:  $a=100$ y $b=0.5$
# ### Grafico 2:  $a=0.5$ y $b=100$

# %%
fig = plt.figure()
ax = fig.add_subplot(121)# *nrows*, *ncols*, and *index*
ax.set_title('GRAFICO 1')
ax.set_ylabel('Y')
ax.set_xlabel('X')

ax_2 = fig.add_subplot(122)# *nrows*, *ncols*, and *index*
ax_2.set_title('GRAFICO 2')
ax_2.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# ## Dibujar los siguientes puntos:

# %%
puntos = np.array([(0,4), (1,10), (2,2), (3,7), (4,9), (4,2), (5,9), (6,10), (7,15), (8,110),])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.grid(True) # opcional.
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Dibujar los siguientes puntos:

# %%
puntos_3d = np.array([(0,4,10), (1,10,16), (2,2,20), (3,7,25), (4,9,30), (4,2,2), (5,9, 3), (6,10,4), (7,15,6), (8,110,9),])

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(np.random.random_sample(size=20), 
           np.random.random_sample(size=20), 
           np.random.random_sample(size=20), s=50, c="b", depthshade=True, label="Azul")

ax.legend()

# %%
## Realizar un grafico de barras:

# %%
data = {
    'Nombre':['Juan', 'Caro', 'Rodrigo', 'Ana', 'Virginia'],
    'Altura':[2, 1.5, 1.7, 1.66, 1.90]
}

# %%
data["Nombre"]
# Out:
# ['Juan', 'Caro', 'Rodrigo', 'Ana', 'Virginia']

# %%
data['Altura']
# Out:
# [2, 1.5, 1.7, 1.66, 1.9]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x_value = 
y_value = 
ax.bar(x_value, y_value, align='center')
ax.set_xticks([0, 1, 2, 3])
ax.set_xticklabels(["algo", "algo_1", "algo_2", "algo_3"])
ax.set_ylabel('%')
ax.set_title('Algo')
# Out:
# Text(0.5, 1.0, 'Algo')

# %% [markdown]
# ## Descargar una imagen de internet y mostrarla

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_yticks([])
ax.set_xticks([])
ax.imshow(ACAVARIABLEIMAGEN)

# %% [markdown]
# ## Realizar un corte a la imagen

# %%
crop =

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_yticks([])
ax.set_xticks([])
ax.imshow(crop)

# %% [markdown]
# ## Rotar una imagen
